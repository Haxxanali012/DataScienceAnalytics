# %% [markdown]
# <a href="https://colab.research.google.com/github/Haxxanali012/DataScienceAnalytics/blob/main/Lab15_20sw012.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#    **Name: M Hassan**
#
#    **Roll no: 20sw012**
#
#    **Section: ii**

# %%
import pandas as pd
movie = pd.read_csv("/content/movie.csv")
movie.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
movie = movie.loc[:,["movieId","title"]]
movie.head(10)
# Out:
#    movieId                               title
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)

# %%
rating = pd.read_csv("/content/rating.csv")
rating.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
rating = rating.loc[:,["userId","movieId","rating"]]
rating.head(10)
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5
# 5       1      112     3.5
# 6       1      151     4.0
# 7       1      223     4.0
# 8       1      253     4.0
# 9       1      260     4.0

# %%
data = pd.merge(movie,rating)
data.head(10)
# Out:
#    movieId             title  userId  rating
# 0        1  Toy Story (1995)       3     4.0
# 1        1  Toy Story (1995)       6     5.0
# 2        1  Toy Story (1995)       8     4.0
# 3        1  Toy Story (1995)      10     4.0
# 4        1  Toy Story (1995)      11     4.5
# 5        1  Toy Story (1995)      12     4.0
# 6        1  Toy Story (1995)      13     4.0
# 7        1  Toy Story (1995)      14     4.5
# 8        1  Toy Story (1995)      16     3.0
# 9        1  Toy Story (1995)      19     5.0

# %%
data.shape
# Out:
# (2217184, 4)

# %%
data = data.iloc[:1000000,:]

# %%
pivot_table = data.pivot_table(index = ["userId"],columns = ["title"],values = "rating")
pivot_table.head(10)
# Out:
# title   'Til There Was You (1997)  1-900 (06) (1994)  101 Dalmatians (1996)  \
# userId
# 1                             NaN                NaN                    NaN
# 2                             NaN                NaN                    NaN
# 3                             NaN                NaN                    NaN
# 4                             NaN                NaN                    NaN
# 5                             NaN                NaN                    NaN
# 6                             NaN                NaN                    NaN
# 7                             NaN                NaN                    NaN
# 8                             NaN                NaN                    NaN
# 9                             NaN                NaN                    NaN
# 10                            NaN                NaN                    NaN
#
# title   12 Angry Men (1957)  187 (One Eight Seven) (1997)  \
# userId
# ...

# %%
movie_watched = pivot_table["Bad Boys (1995)"]
similarity_with_other_movies = pivot_table.corrwith(movie_watched)
similarity_with_other_movies = similarity_with_other_movies.sort_values(ascending=False)
similarity_with_other_movies.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# title
# Parallel Sons (1995)                     1.0
# Twisted (1996)                           1.0
# Wend Kuuni (a.k.a. God's Gift) (1982)    1.0
# Mad Dog Time (1996)                      1.0
# Touki Bouki (1973)                       1.0
# dtype: float64

# %% [markdown]
# **Movie-Recommendation-System**
#
# **1-User based recommendation systems**
#
# **2-Item based recommendation systems**
#
# **3-We make very basic movie recommendation system**
